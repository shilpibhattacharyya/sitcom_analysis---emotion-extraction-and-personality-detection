# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', -1)

# %%
import re
bb_chars={} 
Walter=''
Skyler=''
Jesse=''
Hank=''
Marie=''

with open("breaking_bad_transcripts/season1/1.txt", "r+") as fp:
    for cnt, line in enumerate(fp):
#         if line.startswith('Scene: '):
#             Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
            #print(Scene)
        if line.startswith('Walter:'):
            #string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Walter=Walter+ ' '+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#+ re.sub(r'\(.*\)', '', string)
            #print(Raj)
        if line.startswith('Skyler:'):
            #string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Skyler=Skyler+ ' '+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
            #print(Penny)
        if line.startswith('Jesse:'):
            #string=Scene.replace("\n", "")+"*"+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Jesse=Jesse+ ' '+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
        if line.startswith('Hank:'):
            #string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Hank=Hank+ ' '+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
            
        if line.startswith('Marie:'):
            #string=Scene.replace("\n", "")+"*"+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Marie=Marie+ ' '#re.sub(r'\(.*\)')#, '', string)
bb_chars['Walter']=Walter
bb_chars['Skyler']=Skyler
bb_chars['Jesse']=Jesse
bb_chars['Hank']=Hank
bb_chars['Marie']=Marie


##Raj
s=pd.Series(bb_chars['Walter'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
# df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s=df1.Text
# df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df1['Text']=s
df1['Speaker']='Walter'
df1['Season']='1'

##Penny
s1=pd.Series(bb_chars['Skyler'].split('\n'))
df2 = pd.DataFrame({'Text':s1.values})
# df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s1=df2.Text
# df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])

# df2['Text']=s1
df2['Speaker']='Skyler'
df2['Season']='1'

##Sheldon
s2=pd.Series(bb_chars['Jesse'].split('\n'))
df3 = pd.DataFrame({'Text':s2.values})
# df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s2=df3.Text
# df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df3['Text']=s2
df3['Speaker']='Jesse'
df3['Season']='1'

##Leonard
s3=pd.Series(bb_chars['Jesse'].split('\n'))
df4 = pd.DataFrame({'Text':s3.values})
# df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s3=df4.Text
# df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df4['Text']=s3
df4['Speaker']='Hank'
df4['Season']='1'

##Raj
s4=pd.Series(bb_chars['Marie'].split('\n'))
df5 = pd.DataFrame({'Text':s4.values})
# df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s4=df1.Text
# df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df5['Text']=s4
df5['Speaker']='Marie'
df5['Season']='1'

df_1 = pd.concat([df1, df2,df3,df4,df5])
df_1 = df_1.sample(frac=1).reset_index(drop=True)

df_1.head()
# Out:
#                                             Text Speaker Season
# 0   Yeah. I mean I used to until you killed him.  Jesse   1
# 1   Gone to your lymph nodes.                     Hank    1
# 2   What do you mean? To like a distributor?      Hank    1
# 3   3-A.                                          Walter  1
# 4   How long?                                     Walter  1

# %%
import re
bb_chars={} 
Walter=''
Skyler=''
Jesse=''
Hank=''
Marie=''

with open("breaking_bad_transcripts/season2/2.txt", "r+") as fp:
    for cnt, line in enumerate(fp):
#         if line.startswith('Scene: '):
#             Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
            #print(Scene)
        if line.startswith('Walter:'):
            #string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Walter=Walter+ ' '+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#+ re.sub(r'\(.*\)', '', string)
            #print(Raj)
        if line.startswith('Skyler:'):
            #string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Skyler=Skyler+ ' '+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
            #print(Penny)
        if line.startswith('Jesse:'):
            #string=Scene.replace("\n", "")+"*"+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Jesse=Jesse+ ' '+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
        if line.startswith('Hank:'):
            #string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Hank=Hank+ ' '+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
            
        if line.startswith('Marie:'):
            #string=Scene.replace("\n", "")+"*"+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Marie=Marie+ ' '#re.sub(r'\(.*\)')#, '', string)
bb_chars['Walter']=Walter
bb_chars['Skyler']=Skyler
bb_chars['Jesse']=Jesse
bb_chars['Hank']=Hank
bb_chars['Marie']=Marie


##Raj
s=pd.Series(bb_chars['Walter'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
# df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s=df1.Text
# df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df1['Text']=s
df1['Speaker']='Walter'
df1['Season']='2'

##Penny
s1=pd.Series(bb_chars['Skyler'].split('\n'))
df2 = pd.DataFrame({'Text':s1.values})
# df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s1=df2.Text
# df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])

# df2['Text']=s1
df2['Speaker']='Skyler'
df2['Season']='2'

##Sheldon
s2=pd.Series(bb_chars['Jesse'].split('\n'))
df3 = pd.DataFrame({'Text':s2.values})
# df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s2=df3.Text
# df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df3['Text']=s2
df3['Speaker']='Jesse'
df3['Season']='2'

##Leonard
s3=pd.Series(bb_chars['Jesse'].split('\n'))
df4 = pd.DataFrame({'Text':s3.values})
# df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s3=df4.Text
# df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df4['Text']=s3
df4['Speaker']='Hank'
df4['Season']='2'

##Raj
s4=pd.Series(bb_chars['Marie'].split('\n'))
df5 = pd.DataFrame({'Text':s4.values})
# df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s4=df1.Text
# df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df5['Text']=s4
df5['Speaker']='Marie'
df5['Season']='2'

df_2 = pd.concat([df1, df2,df3,df4,df5])
df_2 = df_2.sample(frac=1).reset_index(drop=True)

df_2.head()
# Out:
#                                                                                                                    Text  \
# 0   Actually its not as bad as it sounds. Its a fairly common occurrence. Easily treated. In fact the news is all good.
# 1   Can he get it running again?
# 2   Hey...no...no man. No...
# 3   Okay can you at least tell me why?
# 4   38 pounds. Ready to go at a moments notice. [Gus gets up] Will I hear from you?
#
#   Speaker Season
# 0  Walter  2
# 1  Walter  2
# 2  Jesse   2
# 3  Walter  2
# 4  Walter  2

# %%
import re
bb_chars={} 
Walter=''
Skyler=''
Jesse=''
Hank=''
Marie=''

with open("breaking_bad_transcripts/season2/2.txt", "r+") as fp:
    for cnt, line in enumerate(fp):
#         if line.startswith('Scene: '):
#             Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
            #print(Scene)
        if line.startswith('Walter:'):
            #string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Walter=Walter+ ' '+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#+ re.sub(r'\(.*\)', '', string)
            #print(Raj)
        if line.startswith('Skyler:'):
            #string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Skyler=Skyler+ ' '+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
            #print(Penny)
        if line.startswith('Jesse:'):
            #string=Scene.replace("\n", "")+"*"+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Jesse=Jesse+ ' '+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
        if line.startswith('Hank:'):
            #string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Hank=Hank+ ' '+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
            
        if line.startswith('Marie:'):
            #string=Scene.replace("\n", "")+"*"+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Marie=Marie+ ' '#re.sub(r'\(.*\)')#, '', string)
bb_chars['Walter']=Walter
bb_chars['Skyler']=Skyler
bb_chars['Jesse']=Jesse
bb_chars['Hank']=Hank
bb_chars['Marie']=Marie


##Raj
s=pd.Series(bb_chars['Walter'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
# df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s=df1.Text
# df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df1['Text']=s
df1['Speaker']='Walter'
df1['Season']='3'

##Penny
s1=pd.Series(bb_chars['Skyler'].split('\n'))
df2 = pd.DataFrame({'Text':s1.values})
# df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s1=df2.Text
# df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])

# df2['Text']=s1
df2['Speaker']='Skyler'
df2['Season']='3'

##Sheldon
s2=pd.Series(bb_chars['Jesse'].split('\n'))
df3 = pd.DataFrame({'Text':s2.values})
# df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s2=df3.Text
# df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df3['Text']=s2
df3['Speaker']='Jesse'
df3['Season']='3'

##Leonard
s3=pd.Series(bb_chars['Jesse'].split('\n'))
df4 = pd.DataFrame({'Text':s3.values})
# df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s3=df4.Text
# df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df4['Text']=s3
df4['Speaker']='Hank'
df4['Season']='3'

##Raj
s4=pd.Series(bb_chars['Marie'].split('\n'))
df5 = pd.DataFrame({'Text':s4.values})
# df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s4=df1.Text
# df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df5['Text']=s4
df5['Speaker']='Marie'
df5['Season']='3'

df_3 = pd.concat([df1, df2,df3,df4,df5])
df_3 = df_3.sample(frac=1).reset_index(drop=True)

df_3.head()
# Out:
#                                                                     Text  \
# 0   Look that is completely uncool alright? We agreed 50/50 partners!
# 1
# 2   I woke up. I found her. Thats all I know.
# 3   Whatd you do huh? Shes lying there dying and where the hell are you?
# 4   Nothing. Im sorry I just...
#
#   Speaker Season
# 0  Hank    3
# 1  Hank    3
# 2  Jesse   3
# 3  Hank    3
# 4  Hank    3

# %%
import re
bb_chars={} 
Walter=''
Skyler=''
Jesse=''
Hank=''
Marie=''

with open("breaking_bad_transcripts/season2/2.txt", "r+") as fp:
    for cnt, line in enumerate(fp):
#         if line.startswith('Scene: '):
#             Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
            #print(Scene)
        if line.startswith('Walter:'):
            #string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Walter=Walter+ ' '+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#+ re.sub(r'\(.*\)', '', string)
            #print(Raj)
        if line.startswith('Skyler:'):
            #string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Skyler=Skyler+ ' '+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
            #print(Penny)
        if line.startswith('Jesse:'):
            #string=Scene.replace("\n", "")+"*"+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Jesse=Jesse+ ' '+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
        if line.startswith('Hank:'):
            #string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Hank=Hank+ ' '+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
            
        if line.startswith('Marie:'):
            #string=Scene.replace("\n", "")+"*"+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Marie=Marie+ ' '#re.sub(r'\(.*\)')#, '', string)
bb_chars['Walter']=Walter
bb_chars['Skyler']=Skyler
bb_chars['Jesse']=Jesse
bb_chars['Hank']=Hank
bb_chars['Marie']=Marie


##Raj
s=pd.Series(bb_chars['Walter'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
# df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s=df1.Text
# df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df1['Text']=s
df1['Speaker']='Walter'
df1['Season']='4'

##Penny
s1=pd.Series(bb_chars['Skyler'].split('\n'))
df2 = pd.DataFrame({'Text':s1.values})
# df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s1=df2.Text
# df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])

# df2['Text']=s1
df2['Speaker']='Skyler'
df2['Season']='4'

##Sheldon
s2=pd.Series(bb_chars['Jesse'].split('\n'))
df3 = pd.DataFrame({'Text':s2.values})
# df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s2=df3.Text
# df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df3['Text']=s2
df3['Speaker']='Jesse'
df3['Season']='4'

##Leonard
s3=pd.Series(bb_chars['Jesse'].split('\n'))
df4 = pd.DataFrame({'Text':s3.values})
# df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s3=df4.Text
# df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df4['Text']=s3
df4['Speaker']='Hank'
df4['Season']='4'

##Raj
s4=pd.Series(bb_chars['Marie'].split('\n'))
df5 = pd.DataFrame({'Text':s4.values})
# df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s4=df1.Text
# df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df5['Text']=s4
df5['Speaker']='Marie'
df5['Season']='4'

df_4 = pd.concat([df1, df2,df3,df4,df5])
df_4 = df_4.sample(frac=1).reset_index(drop=True)

df_4.head()
# Out:
#                                                                                                                                                                                                                                                 Text  \
# 0   But first things first we gotta get more dealers yknow foot soldiers alright? Now theyll be working for you youre working for me and Im working for you. You follow me? Layered like nachos. Exponential growth. Thats success with a capital S.
# 1   Your half? There is no your half of the money! There is only my all of it do you understand?! Why why should I be penalized because of your sloppiness?!
# 2   How significant?
# 3   How about we get him a real attorney? I mean what the hell is this? This is who he hires?
# 4   Thats awesome! Serious? Thats...thats...thats great man! My aunt she never...I mean yknow at your stage I didnt even think that could happen.
#
#   Speaker Season
# 0  Hank    4
# 1  Walter  4
# 2  Jesse   4
# ...

# %%
import re
bb_chars={} 
Walter=''
Skyler=''
Jesse=''
Hank=''
Marie=''

with open("breaking_bad_transcripts/season2/2.txt", "r+") as fp:
    for cnt, line in enumerate(fp):
#         if line.startswith('Scene: '):
#             Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
            #print(Scene)
        if line.startswith('Walter:'):
            #string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Walter=Walter+ ' '+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#+ re.sub(r'\(.*\)', '', string)
            #print(Raj)
        if line.startswith('Skyler:'):
            #string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Skyler=Skyler+ ' '+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
            #print(Penny)
        if line.startswith('Jesse:'):
            #string=Scene.replace("\n", "")+"*"+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Jesse=Jesse+ ' '+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
        if line.startswith('Hank:'):
            #string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Hank=Hank+ ' '+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))#re.sub(r'\(.*\)')#, '', string)
            
        if line.startswith('Marie:'):
            #string=Scene.replace("\n", "")+"*"+(line[7:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Marie=Marie+ ' '#re.sub(r'\(.*\)')#, '', string)
bb_chars['Walter']=Walter
bb_chars['Skyler']=Skyler
bb_chars['Jesse']=Jesse
bb_chars['Hank']=Hank
bb_chars['Marie']=Marie


##Raj
s=pd.Series(bb_chars['Walter'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
# df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s=df1.Text
# df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df1['Text']=s
df1['Speaker']='Walter'
df1['Season']='5'

##Penny
s1=pd.Series(bb_chars['Skyler'].split('\n'))
df2 = pd.DataFrame({'Text':s1.values})
# df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s1=df2.Text
# df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])

# df2['Text']=s1
df2['Speaker']='Skyler'
df2['Season']='5'

##Sheldon
s2=pd.Series(bb_chars['Jesse'].split('\n'))
df3 = pd.DataFrame({'Text':s2.values})
# df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s2=df3.Text
# df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df3['Text']=s2
df3['Speaker']='Jesse'
df3['Season']='5'

##Leonard
s3=pd.Series(bb_chars['Jesse'].split('\n'))
df4 = pd.DataFrame({'Text':s3.values})
# df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s3=df4.Text
# df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df4['Text']=s3
df4['Speaker']='Hank'
df4['Season']='5'

##Raj
s4=pd.Series(bb_chars['Marie'].split('\n'))
df5 = pd.DataFrame({'Text':s4.values})
# df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(),
#                                    columns = ['Scene','Text'])
# s4=df1.Text
# df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
#                                     columns = ['Location','Scene'])
# df5['Text']=s4
df5['Speaker']='Marie'
df5['Season']='5'

df_5 = pd.concat([df1, df2,df3,df4,df5])
df_5 = df_5.sample(frac=1).reset_index(drop=True)

df_5.head()
# Out:
#                                                                                                                                                                                                                                                                                        Text  \
# 0   We got to be Tuco. Alright cut out the middle man run our own game.
# 1   Thats not how it happened.
# 2   You tell me Skyler. You tell me exactly what it is you think Im lying about. What an affair? Im having an affair? Is that what you think?
# 3   Yeah? Well you dont get to vote.
# 4   Look you remember Emilio? Kay this dude got Emilio off like twice. Kay both times they had him dead to rights yo and then poof. Dudes like Houdini. Seriously when the going gets tough you dont want a criminal lawyer all right? You want a criminal lawyer. You know what Im saying?
#
#   Speaker Season
# 0  Hank    5
# 1  Jesse   5
# 2  Walter  5
# 3  Jesse   5
# 4  Hank    5

# %%
df = pd.concat([df_5,df_4,df_3,df_2,df_1])
df = df.sample(frac=1).reset_index(drop=True)

df.to_csv('breaking_bad_dataset.csv')

# %%
df.head(50)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Text  \
# 0    [in a calm tone] - Then what do you suggest we do? I dont think either of us are eager to jump into bed with another Tuco.
# ...

# %%
df.shape
# Out:
# (1919, 3)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                        Text  \
# 0   [in a calm tone] - Then what do you suggest we do? I dont think either of us are eager to jump into bed with another Tuco.
# 1   Look you remember Emilio? Kay this dude got Emilio off like twice. Kay both times they had him dead to rights yo and then poof. Dudes like Houdini. Seriously when the going gets tough you dont want a criminal lawyer all right? You want a criminal lawyer. You know what Im saying?
# 2   You are joking right? If I gave you that money you would be dead inside of a week.
# 3   Yeah damn straight. Know why? Cause we do things my way this time or I walk! You need me more than I need you...Walt.
# 4   Stay out of my territory.
#
#   Speaker Season
# 0  Walter  4
# 1  Jesse   5
# ...
