# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', -1)

# %%
# import re
# friends_chars={} 
# Rachel=''
# Ross=''
# Joey=''
# Chandler=''
# Phoebe=''
# Monica=''
# with open("transcripts_friends/season_all/merged.csv", "r+") as fp:
#     for cnt, line in enumerate(fp):
#         if line.startswith('Rachel:'):
#             string=(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
#             Rachel=Rachel+re.sub(r'\(.*\)', '', string)
#         elif line.startswith('Ross:'):
#             string=(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
#             Ross=Ross+re.sub(r'\(.*\)', '', string)
#         elif line.startswith('Monica:'):
#             string=(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
#             Monica=Monica+re.sub(r'\(.*\)', '', string)
#         elif line.startswith('Chandler:'):
#             string=(line[10:].replace(":", "").replace('"', '').replace(",", ""))
#             Chandler=Chandler+re.sub(r'\(.*\)', '', string)
#         if line.startswith('Phoebe:'):
#             string=(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
#             Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
#         if line.startswith('Joey:'):
#             string=(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
#             Joey=Joey+re.sub(r'\(.*\)', '', string)

# friends_chars['RACHEL']=Rachel
# friends_chars['ROSS']=Ross
# friends_chars['MONICA']=Monica
# friends_chars['PHOEBE']=Phoebe
# friends_chars['CHANDLER']=Chandler
# friends_chars['JOEY']=Joey

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season1/merged1.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string="("+"Scene:"+Scene.replace("\n", "")+")"+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string="("+"Scene:"+Scene.replace("\n", "")+")"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string="("+"Scene:"+Scene.replace("\n", "")+")"+(line[10:].replace(":", "").replace('"', '').replace(",", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string="("+"Scene:"+Scene.replace("\n", "")+")"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string="("+"Scene:"+Scene.replace("\n", "")+")"+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)

friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})

df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(),
                                   columns = ['Scene','Text'])

s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='1'

df1.head(30)
# Out:
#                Location                                            Scene  \
# 0    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 1    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 2    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 3    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 4    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 5    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 6    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 7    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 8    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 9    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 10   Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 11   Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 12   A Restaurant         Monica and Paul are eating,
# 13   Monica's Apartment   Rachel is watching Joanne Loves Chaci,
# 14   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 15   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 16   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 17   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 18   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 19   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 20   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 21   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 22   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 23   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 24   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 25   Central Perk         everyone but Rachel is there,
# 26   Central Perk         everyone but Rachel is there,
# 27   Central Perk         everyone but Rachel is there,
# 28   Central Perk         everyone but Rachel is there,
# 29   Central Perk         everyone but Rachel is there,
#
#                                                                                                                                                                                                                                                                                                                                                                                       Text  \
# 0   Oh God Monica hi! Thank God! I just went to your building and you werent there and then this guy with a big hammer said you might be here and you are you are!
# 1   Hi sure!
# 2   Oh God... well it started about a half hour before the wedding. I was in the room where we were keeping all the presents and I was looking at this gravy boat. This really gorgeous Lamauge gravy boat. When all of a sudden-  So anyway I just didnt know where to go and I know that you and I have kinda drifted apart but youre the only person I knew who lived here in the city.
# 3   Ooh I was kinda hoping that wouldnt be an issue... [Scene Monicas Apartment everyone is there and watching a Spanish Soap on TV and are trying to figure out what is going on.]
# 4    Daddy I just... I cant marry him! Im sorry. I just dont love him. Well it matters to me!
# 1780   Monica and Rachel's
# 1781   Monica and Rachel's
# 1782   Monica and Rachel's
# 1783   Monica and Rachel's
# 1784   Monica and Rachel's
# 1785   Monica and Rachel's
# 1786   Monica and Rachel's
# 1787   Monica and Rachel's
# 1788   Monica and Rachel's
# 1789   Monica and Rachel's Balcony
# 1790   Monica and Rachel's Balcony
# 1791   Monica and Rachel's Balcony
# 1792   Monica and Rachel's Balcony
# 1793   Monica and Rachel's Balcony
# 1794   Monica and Rachel's Balcony
# 1795   Monica and Rachel's Balcony
# 1796   Monica and Rachel's Balcony
# 1797   Monica and Rachel's Balcony
# 1798   Monica and Rachel's Balcony
# 1799   Monica and Rachel's Balcony
# 1800   Monica and Rachel's Balcony
# 1801   Airport
# 1802
#
#                                                                                                                                                                                                                    Scene  \
# 0      Chandler, Joey, Phoebe, and Monica are there,
# 1      Chandler, Joey, Phoebe, and Monica are there,
# 2      Chandler, Joey, Phoebe, and Monica are there,
# 3      Chandler, Joey, Phoebe, and Monica are there,
# 4      Chandler, Joey, Phoebe, and Monica are there,
# 5      Chandler, Joey, Phoebe, and Monica are there,
# 6      Chandler, Joey, Phoebe, and Monica are there,
# 7      Chandler, Joey, Phoebe, and Monica are there,
# 8      Chandler, Joey, Phoebe, and Monica are there,
# 9      Chandler, Joey, Phoebe, and Monica are there,
# 10     Chandler, Joey, Phoebe, and Monica are there,
# 11     Chandler, Joey, Phoebe, and Monica are there,
# 12     Monica and Paul are eating,
# 13     Rachel is watching Joanne Loves Chaci,
# 14     Rachel is making coffee for Joey and Chandler,
# 15     Rachel is making coffee for Joey and Chandler,
# 16     Rachel is making coffee for Joey and Chandler,
# 17     Rachel is making coffee for Joey and Chandler,
# 18     Rachel is making coffee for Joey and Chandler,
# 19     Rachel is making coffee for Joey and Chandler,
# 20     Rachel is making coffee for Joey and Chandler,
# 21     Rachel is making coffee for Joey and Chandler,
# 22     Rachel is making coffee for Joey and Chandler,
# 23     Rachel is making coffee for Joey and Chandler,
# 24     Rachel is making coffee for Joey and Chandler,
# 25     everyone but Rachel is there,
# 26     everyone but Rachel is there,
# 27     everyone but Rachel is there,
# 28     everyone but Rachel is there,
# 29     everyone but Rachel is there,
# ...                              ...
# 1773   Ross has headphones on, and is listening to a 'How To Speak Chinese' tape, Occasionally, he makes an outburst in Chinese in accordance with the tape, He is getting on the jetway, The flight attendant is there,
# 1774   Monica, Phoebe, and Rachel are there, Monica is holding the wrapping paper from one of Rachel's gifts,
# 1775   Monica, Phoebe, and Rachel are there, Monica is holding the wrapping paper from one of Rachel's gifts,
# 1776   Monica, Phoebe, and Rachel are there, Monica is holding the wrapping paper from one of Rachel's gifts,
# 1777   Monica, Phoebe, and Rachel are there, Monica is holding the wrapping paper from one of Rachel's gifts,
# 1778   Monica, Phoebe, and Rachel are there, Monica is holding the wrapping paper from one of Rachel's gifts,
# 1779   Monica, Phoebe, and Rachel are there, Monica is holding the wrapping paper from one of Rachel's gifts,
# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season1/merged1.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='1'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='1' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='1'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='1'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='1'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='1'                            
df6.head(20)

df_1 = pd.concat([df1, df2,df3,df4,df5,df6])
df_1 = df_1.sample(frac=1).reset_index(drop=True)

df_1.head()
df2.head()
# Out:
#         Location                                           Scene  \
# 0   Central Perk   Chandler, Joey, Phoebe, and Monica are there,
# 1   Central Perk   Chandler, Joey, Phoebe, and Monica are there,
# 2   Central Perk   Chandler, Joey, Phoebe, and Monica are there,
# 3   Central Perk   Chandler, Joey, Phoebe, and Monica are there,
# 4   Central Perk   Chandler, Joey, Phoebe, and Monica are there,
#
#                                                                                                                                    Text  \
# 0   Hi.
# 1  I just feel like someone reached down my throat, grabbed my small intestine, pulled it out of my mouth and tied it around my neck...
# 2  Thanks.
# 3  No, no don't! Stop cleansing my aura! No, just leave my aura alone, okay?
# 4  I'll be fine, alright? Really, everyone. I hope she'll be very happy.
#
#   Speaker Season
# 0  Ross    1
# 1  Ross    1
# 2  Ross    1
# 3  Ross    1
# 4  Ross    1

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season2/merged2.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='2'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df2['Speaker']='Ross'
df2['Season']='2' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='2'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='2'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='2'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='2'                            
df6.head(20)

df_2 = pd.concat([df1, df2,df3,df4,df5,df6])
df_2 = df_2.sample(frac=1).reset_index(drop=True)

df_2.head()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:107: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                 Location  \
# 0   Monica and Rachel's
# 1   Central Perk
# 2   Monica and Rachel's
# 3   Central Perk
# 4   The Department Store
#
#                                                                                                      Scene  \
# 0   the next morning,
# 1   Ross and Chandler enter,
# 2   Monica is recovering from her haircut, Phoebe is playing her doctor and is coming in from the bedroom,
# 3   the gang is all there,
# 4   Joey is trying to sell some cologne,
#
#   Season   Speaker  \
# 0  2      Phoebe
# 1  2      Rachel
# 2  2      Chandler
# 3  2      Chandler
# 4  2      Joey
#
#                                                                                                               Text
# 0  What's goin' on?
# 1  Thank you.
# 2   Your tailor is a very bad man!
# 3  Come on, you're going to Bloomingdale's with Julie? That's like cheating on Rachel in her house of worship.
# 4   Hey, Annabelle, Uh, listen, I was wondering if maybe after work you and I could go maybe grab a cup of coffee.

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season3/merged3.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='3'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='3' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='3'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='3'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='3'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='3'                            
df6.head(20)

df_3 = pd.concat([df1, df2,df3,df4,df5,df6])
df_3 = df_3.sample(frac=1).reset_index(drop=True)

df_3.head()
# Out:
#                Location  \
# 0   Monica and Rachel's
# 1   Ross’s
# 2   Rachel’s office
# 3   Monica’s Bedroom
# 4   Monica and Rachel's
#
#                                                                                          Scene  \
# 0   continued from earlier
# 1   the gang, minus Rachel of course, is there, Chandler is forced to smoke by an open window,
# 2   Chandler and her are coming back from lunch,
# 3   Monica and Phoebe are removing the rest of their wax strips,
# 4   Ross is eating the picnic as Rachel comes home from work,
#
#                                                                                                                                                                Text  \
# 0  What?
# 1  Look, you guys I just wanna say, I really, really appreciate you spending this time with me. It’s been a pretty hard time right now, so I just wanna say thanks.
# 2  No!! No! He’s not married, or involved, with anyone!
# 3  Uh-oh.
# 4  Okay, it’s not, it’s not.
#
#     Speaker Season
# 0  Ross      3
# 1  Ross      3
# 2  Rachel    3
# 3  Chandler  3
# 4  Ross      3

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season4/merged4.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='4'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='4' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='4'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='4'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='4'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='4'                            
df6.head(20)

df_4 = pd.concat([df1, df2,df3,df4,df5,df6])
df_4 = df_4.sample(frac=1).reset_index(drop=True)

df_4.head()
# Out:
#                    Location  \
# 0   The beach house
# 1   Chandler and Joey's
# 2   Chandler and Joey's erm
# 3   The beach house
# 4   The beach house
#
#                                                                                                                                                                                                           Scene  \
# 0   it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,
# 1   erm, Monica and Rachel's, Chandler, Monica, and Phoebe are returning from the strip club,
# 2   Monica and Rachel's, Rachel and Joey are standing at the counter, Monica is flipping a light switch on and off next to the door,
# 3   Joey and Chandler are sitting at the dinner table, Monica is looking in the fridge,
# 4   Joey and Chandler are sitting at the dinner table, Monica is looking in the fridge,
#
#                                   Text   Speaker Season
# 0  Yeah.                                Ross      4
# 1  Stripping!                           Chandler  4
# 2   Hello!                              Chandler  4
# 3  Sweety, what are you talking about?  Monica    4
# 4  Oh.                                  Monica    4

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season5/merged5.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='5'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='5' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='5'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='5'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='5'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='5'                            
df6.head(20)

df_5 = pd.concat([df1, df2,df3,df4,df5,df6])
df_5 = df_5.sample(frac=1).reset_index(drop=True)

df_5.head()
# Out:
#         Location  \
# 0   Central Perk
# 1   Central Perk
# 2   Central Perk
# 3   Chandler
# 4   Central Perk
#
#                                                                                                                                                                                                                                                                                        Scene  \
# 0   Joey, Chandler, and Monica are there as Phoebe enters carrying a large box,
# 1   Ross is drinking some Alka-Seltzer, The rest of the gang, minus Rachel is there as well,
# 2   Gary, Phoebe, Monica, and Chandler are there,
# 3   Joey, and Ross's; Joey returns carrying a bucket of chicken, and starts going through the mail, While doing this, Monica's picture falls out, He bends over to pick it up and gasps, While he's staring at the picture, Rachel decides to come over and sees him looking at the picture,
# 4   Phoebe is drinking coffee as Chandler enters,
#
#                                                                          Text  \
# 0  What is that?
# 1  Honey, come on! You live far away! You're not related. You lift right out.
# 2  No, but it is fast. Isn't it?
# 3   Oh my God! That's Monica!!
# 4  Hmm, did you talk to Gary about the moving in thing?
#
#   Speaker Season
# 0  Monica  5
# 1  Rachel  5
# 2  Phoebe  5
# 3  Rachel  5
# 4  Phoebe  5

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season6/merged6.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='6'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='6' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='6'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='6'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='6'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='6'                            
df6.head(20)

df_6 = pd.concat([df1, df2,df3,df4,df5,df6])
df_6 = df_6.sample(frac=1).reset_index(drop=True)

df_6.head()
# Out:
#                              Location  \
# 0   Ross's apartment
# 1   Monica and Rachel's
# 2   Ross and Carol's
# 3   Phoebe and Rachel’s new apartment
# 4   Central Perk
#
#                                                                                                                                                                                                                                                      Scene  \
# 0   Ross is coming in from doing his laundry, He starts folding it as Chandler enters,
# 1   Chandler is talking to Phoebe about trying to give Joey some money,
# 2   Carol is working on something at the table and Ross is reading a newspaper on the couch,
# 3   Rachel and Phoebe are making their answering machine message,
# 4   Chandler is reading on the couch while Joey, still suffering from his hernia, is returning with coffee for them both, After a series of grunts and groans he manages to painfully walk back from the counter, sit down, and slide Chandler his coffee,
#
#                                                                  Text  \
# 0  Wait a minute, I can’t give this to her.
# 1  Hey! So you guys have anything planned for the big last night?
# 2  Oh.
# 3  Phoebe, come on that's silly.
# 4  No-no, it’ll be fun! We can come back and we can haunt these guys!
#
#     Speaker Season
# 0  Chandler  6
# 1  Phoebe    6
# 2  Ross      6
# 3  Rachel    6
# 4  Phoebe    6

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season7/merged7.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='7'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='7' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='7'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='7'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='7'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='7'                            
df6.head(20)

df_7 = pd.concat([df1, df2,df3,df4,df5,df6])
df_7 = df_7.sample(frac=1).reset_index(drop=True)

df_7.head()
# Out:
#                Location  \
# 0   The Movie Set
# 1   Monica’s Hotel Room
# 2   Monica
# 3   Rachel’s birthday
# 4   The Geller’s Garage
#
#                                                                                                                                                Scene  \
# 0   Joey is walking up to the director, pleading with him to let him go,
# 1   Chandler and Monica’s parents and Phoebe are there as Ross enters,
# 2   Chandler, and Phoebe's, Ross lays a lot off small papers, shaped like the U,S, states onto the floor making a map with the states, Phoebe enters
# 3   everyone is presenting their presents to Rachel,
# 4   Monica is picking through her ruined childhood heirlooms with Ross,
#
#                                                                                                                                                Text  \
# 0  No-no-no! We gotta go! Come on!  Here we go.
# 1  Are you okay?
# 2  I hate America! When I finish this game, I swear I am moving.
# 3  No I know, because to be a grandmother you have to be married and have children and I don’t have any of those things. That’s why it’s so funny.
# 4   What?!!!
#
#   Speaker Season
# 0  Joey    7
# 1  Monica  7
# 2  Ross    7
# 3  Rachel  7
# 4  Ross    7

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season8/merged8.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='8'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='8' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='8'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='8'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='8'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='8'                            
df6.head(20)

df_8 = pd.concat([df1, df2,df3,df4,df5,df6])
df_8 = df_8.sample(frac=1).reset_index(drop=True)

df_8.head()
# Out:
#                  Location  \
# 0   Eric’s Apartment
# 1   The Hallway
# 2   Monica and Chandler's
# 3   Monica and Chandler's
# 4   Joey's Apartment
#
#                                                                                 Scene  \
# 0   he’s resting on the bed as Phoebe enters,
# 1   Rachel walks up the stairs and knocks on Joey’s door,
# 2   Brenda is shaking out the rugs on the balcony as Monica pouts in the living room,
# 3   Ross and Rachel are entering with the rest of the gang already inside,
# 4   the guys are still playing the game only everyone is really into it,
#
#                                                                         Text  \
# 0   Ew! Ew! Ew! Ew! Ew! Ew!
# 1  Hey!
# 2  Here’s the plan! Okay? I’m going to leave you get a look at Brenda’s bra!
# 3  Whom.  That’s right.
# 4  Treasure of the Sierra Madre!
#
#     Speaker Season
# 0  Phoebe    8
# 1  Chandler  8
# 2  Monica    8
# 3  Joey      8
# 4  Chandler  8

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season9/merged9.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='9'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='9' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='9'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='9'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='9'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='9'                            
df6.head(20)

df_9 = pd.concat([df1, df2,df3,df4,df5,df6])
df_9 = df_9.sample(frac=1).reset_index(drop=True)

df_9.head()
# Out:
#                                Location  \
# 0   Monica and Chandler's apartment
# 1   Outside Central Perk
# 2   Phoebe's apartment
# 3   hall of the romantic inn in Vermont
# 4   Joey's apartment
#
#                                                                   Scene  \
# 0   Monica sits on the couch and Phoebe is pacing up and down the room,
# 1
# 2   Enter Monica
# 3  None
# 4   Monica enters,
#
#                                                                                                              Text  \
# 0  What are you gonna do?
# 1  I understand. Yeah. Ok so then ok, so we're both living in New York, not seeing anyone. That's so not like us!
# 2  You know, on the way over here, I saw this drunk guy throw up. And then a pigeon ate it!
# 3  That's insane!
# 4  Yeah...
#
#     Speaker Season
# 0  Monica    9
# 1  Phoebe    9
# 2  Monica    9
# 3  Chandler  9
# 4  Monica    9

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season10/merged10.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='10'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='10' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='10'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='10'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='10'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='10'                            
df6.head(20)

df_10 = pd.concat([df1, df2,df3,df4,df5,df6])
df_10 = df_10.sample(frac=1).reset_index(drop=True)

df_10.head()
# Out:
#               Location  \
# 0   Joey's apartment
# 1   Monica's apartment
# 2   Boarding the plane
# 3   Monica's apartment
# 4   Joey and Rachel's
#
#                                                                                                     Scene  \
# 0   Joey and Chandler are still trying to get the birds out of the foosball-table,
# 1   Phoebe enters carrying the horrific 'painting' of Gladys, Monica and Rachel are sitting on the couch,
# 2
# 3
# 4  None
#
#                                                                                                                                      Text  \
# 0  I don't know. Except that, for one last time...  Good game, good game, good game, good game, good game, good game, good game.
# 1   Oh! There's nothing above your bed!!
# 2  What?
# 3  Okay, I have to get that. Now when I get back, I want you and your friends to be gone. Thanksgiving is over. The Vein has spoken.
# 4  Hi! Hey, listen, can we ask you a question? When you and Monica first hooked up, was it weird going from friends to... more than that?
#
#     Speaker Season
# 0  Chandler  10
# 1  Rachel    10
# 2  Phoebe    10
# 3  Monica    10
# 4  Rachel    10

# %%
df = pd.concat([df_10, df_9,df_8,df_7,df_6,df_5,df_4,df_3,df_2,df_1])
df = df.sample(frac=1).reset_index(drop=True)

df.to_csv('friends_dataset.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.head(50)
# Out:
#                                 Location  \
# 0    Coffee place
# 1    Rift’s Restaurant
# 2    Monica and Chandler's
# 3    Chandler and Joey's
# 4    Monica and Rachel's
# 5    Monica and Chandler's
# 6    Caesar's Palace Casino
# 7    The hallway
# 8    A hallway
# 9    Monica and Chandler's
# 10   Joey and Rachel's
# 11   Joey's apartment
# 12   Monica and Chandler's
# 13   Monica and Rachel's
# 14   The Emergency Room
# 15   Central Perk
# 16   a NYU lecture hall
# 17   Joey's apartment
# 18   Monica's apartment
# 19   Monica's apartment
# 20   Monica and Rachel's
# 21   Monica and Rachel's
# 22   Back in New York
# 23   Silvercup Studios
# 24   Central Perk
# 25   Joey and Rachel's
# 26   Ross's bedroom
# 27   Central Perk
# 28   The roof
# 29   Monica
# 30   Boarding the plane
# 31   Monica and Chandler's apartment
# 32   Ross’s apartment
# 33   Monica and Chandler's apartment
# 34   Monica and Rachel's erm
# 35   Monica
# 36   Ross's apartment
# 37   Central Perk
# 38   Silvercup Studios
# 39   Monica and Rachel's
# 40   The New School
# 41   Chandler and Monica’s
# 42   Joey and Rachel's
# 43   Joey's Apartment
# 44   Monica and Rachel's
# 45   Chandler and Monica's future house
# 46   The street in front of Central Perk
# 47   Ross's apartment
# 48   Joey's apartment
# 49   Central Perk
#
#                                                                                                                                                                                       Scene  \
# 0    Joey is there, Chandler is entering
# 1    as seen in Mad About You, Joey and Chandler are there,
# 2    the scene is continued from earlier,
# 3    Chandler is laying on the counter and Rachel and Monica are comforting him again,
# 4    Chandler, Rachel, and Joey are eating, and Phoebe is preparing Ben's milk,
# 5    Chandler is desperately trying to make his Valentine’s Day gift, He takes a paper cup, turns it upside down, sticks two pencils into the top, and hangs a coat hanger from the bottom,
# 6    Joey is approaching one of the blackjack tables on his quest to make enough money for his movie,
# 7    Ross is running up the stairs, Note, This show continues where the last one left off,
# 8    Joey and Ross find Mr, Geller with his ear up against a janitor’s closet door,
# 9    Chandler is sitting on the sofa, reading the newspaper,
# 10   Rachel is filing her nails as Ross and Ben enter,
# 11   Joey and Rachel are eating spaghetti in the living room while watching TV and Rachel drops some on the floor,
# 12   Monica and Chandler are getting ready to go on their honeymoon, Monica is entering from the bedroom,
# 13   the guys are teaching the girls how to play poker,
# 14   Ross is absent,
# 15   Ross is on the couch reading as Rachel enters, It’s the next day,
# 16   the scene is continued from earlier, only Ross has dismissed the class and is now talking to Monica and Rachel,
# 17   Ross is telling Monica and Joey about his date with Elizabeth,
# 18
# 19   Monica and Erica are talking about the baby, and Monica is rubbing Erica's tummy,
# 20   Phoebe is entering with Rachel,
# 21   Ross, Monica, and Joey are playing Monopoly,
# 22   Monica and Chandler in Central Perk on the couch
# 23   Dina is at the craft services table getting some food as Joey walks up,
# 24   Chandler, Joey, Rachel, and Phoebe are there,
# 25   Joey and Rachel are still discussing Bobby and Dina’s situation,
# 26   Ross is working and Rachel is reading a book in bed
# 27   Chandler, Joey, Phoebe, and Monica are there,
# 28   Joey is walking towards Ross with a guy
# 29   Chandler, and Phoebe's, Chandler is sitting at the kitchen table staring at the phone as Monica enters,
# 30
# 31
# 32   Rachel is packing what she still has over there as Ross enters,
# 33  None
# 34   Chandler and Joey's, it is later in the party, The Spin the Bottle game is over and Chandler is making a sandwich as Phoebe watches,
# 35   Chandler, and Phoebe's, Monica is setting the table for dinner as Chandler enters,
# 36   Rachel, Joey and Charlie are eating fajitas when Ross enters from the kitchen,
# 37   Chandler is there,
# 38   a scene is being shot where Dina and Fredrick are celebrating Jessica’s horrible accident by drinking champagne,
# 39   Ben is playing in his crib while Chandler and Ross are leaning against the rim and are completely asleep,
# 40   Monica, carrying her dish, and Joey are confronting the food critic,
# 41   Monica is entering,
# 42   Rachel is filing her nails as Ross and Ben enter,
# 43   the guys are still playing Bamboozled,
# 44   Rachel is trying to apply her eye drops while Monica looks on,
# 45   They enter the living room with the realtor and Joey,
# 46   Steve and Rachel are still there,
# 47   Cassie is eating dinner and Ross is pacing behind her because of what she’s eating,
# 48   He's prying open the drawer with a crowbar to no avail, Monica, Rachel and Chandler enter,
# 49   all are there except Chandler,
#
#    Season   Speaker  \
# 0   9      Ross
# 1   1      Chandler
# 2   8      Rachel
# 3   3      Rachel
# 4   2      Phoebe
# 5   6      Chandler
# 6   5      Joey
# 7   5      Joey
# 8   9      Ross
# 9   9      Monica
# 10  7      Ross
# 11  8      Rachel
# 12  8      Joey
# 13  1      Ross
# 14  1      Ross
# 15  6      Rachel
# 16  6      Monica
# 17  6      Monica
# 18  10     Monica
# 19  10     Monica
# 20  5      Ross
# 21  1      Rachel
# 22  9      Chandler
# 23  7      Joey
# 24  4      Monica
# 25  8      Rachel
# 26  3      Rachel
# 27  1      Monica
# 28  9      Rachel
# 29  6      Chandler
# 30  10     Rachel
# 31  10     Ross
# 32  6      Ross
# 33  9      Monica
# 34  4      Phoebe
# 35  7      Monica
# 36  10     Joey
# 37  4      Rachel
# 38  7      Joey
# 39  2      Ross
# 40  8      Monica
# 41  8      Monica
# 42  7      Rachel
# 43  8      Ross
# 44  5      Monica
# 45  10     Monica
# 46  9      Ross
# 47  7      Ross
# 48  9      Joey
# 49  1      Ross
#
#                                                                                                                                                                                               Text
# 0   Ooh, somebody's getting a little fussy.
# 1   This is unbelievable. It’s been like a half an hour. If this was a cartoon, you’d be looking like a ham right about now.
# 2   Okay, get ready to see some beggin’!
# 3   Yes, and grumpy.
# 4   Ben, dinner!
# 5
# 6   Don’t you see what this means?! I can forget about that stupid movie. I'm gonna be a millionaire!
# 7    Dude! He's right there!
# 8   Dad, what are you doing?
# 9   I'm sorry too.
# 10  Hey listen can you do me a big favor? The dean’s office just called and said there was an urgent meeting. Can you watch Ben for like an hour?
# 11  Oh but look! That’s gonna leave a stain!
# 12  Bye.
# 13  Alright, now, you sure? Phoebe just threw away two jacks because they didn't look happy...
# 14  'Yes', how about. C'mere. Gimme!
# 15  No-no-no! No-no-no! Please Ross, I can’t! I can’t do it!  It’s just gonna freak me out!!!
# 16
# 17  Joey! You didn’t even know her!
# 18  Stinky?!
# 19  Yeah, and I wanted her to get to know the doctors and get settled into the hotel.
# 20  Oh see, I-I needed a new thing for today and there's this leather store that always smells so good and I thought to myself, "Wow,  I never really owned a good smelling pair of pants before."
# 21  And Joey....
# 22  Man, that's some bad advice!
# 23  Yeah.
# 24  All right, you’re hired!
# 25  Hey, now wait a minute! I get when you told people at first that you wanted to be an actor they laughed at you! Now come on Bobby, why don’t you tell us a little bit about your band?
# 26  Yeah.
# 27   Really?
# 28  Joey, you're so sweet.
# 29
# 30  Okay, well keep in mind that by the time you're done, they'll probably be serving dinner.
# 31  Hey!
# 32  Congratulations.
# 33  You are married though.
# 34  What?
# 35  You’re right. I mean I’m sorry. Yeah, I shouldn’t be laughing. I should be laying down papers for you!
# 36  Yeah. I'll see you in the morning.
# 37   Chandler!! You have the best taste in men!
# 38  Oh noo…
# 39  NaN
# 40  I think the things that you said about me are really unfair, and I would like for you to give my bouillabaisse another chance.
# 41  Well, I actually had the weirdest conversation with Joey. He was talking about rules and right and wrong and…
# 42  Uh great! How do you feel about Diet Coke?
# 43  What?!
# 44  All right.
# 45  Ah, so glad you decided to come.
# 46  The first date we've had in months, and they were both such disasters.
# 47   Uh-huh! Uh-huh! And-and-and I’ll always remember that summer because that’s when I realized that we are related.
# 48  Because she is!
# 49  Yeah, which was nice.

# %%
df.count()
# Out:
# Location    93335
# Scene       89825
# Season      93335
# Speaker     93335
# Text        92801
# dtype: int64

# %%
df['Location'].nunique()
# Out:
# 744

# %%
df.groupby('Location')['Text','Speaker']

# %%
from collections import Counter
from matplotlib import pyplot as plt
#print(scene_text)
scenes=df.Location.unique().tolist()
#df1.Location.unique().value_counts()

c=Counter(df.Location)
#print(c.most_common(100))
#len(c)
histo=c.most_common(20)
freq={}
for item,count in histo:
    freq[item]=count
freq
explode = (0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05)
# plt.rcParams["figure.figsize"] = (25,10)
# plt.rcParams.update({'font.size': 30})

plt.pie([float(v) for v in freq.values()], labels=[(k) for k in freq],
           autopct='%.2f',startangle=90, pctdistance=0.85, explode = explode,radius=3,textprops={'fontsize': 35})


centre_circle = plt.Circle((0,0),0.90,fc='white')
fig = plt.gcf()

fig.gca().add_artist(centre_circle)
# Equal aspect ratio ensures that pie is drawn as a circle
#ax1.axis('equal')  
plt.tight_layout()
#plt.title("Top 5 Shoot Locations on F.R.I.E.N.D.S.")

plt.show()

# plt.pie([float(v) for v in freq.values()], labels=[(k) for k in freq],
#            autopct='%.2f')
# plt.show()

# %%
## # friends_chars={} 
# key1 = "Rachel"
# key2="Ross"
# key3="Monica"
# key4="Chandler"
# key5="Phoebe"
# key6="Joey"

# friends_chars.setdefault(key1, [])
# friends_chars.setdefault(key2, [])
# friends_chars.setdefault(key3, [])
# friends_chars.setdefault(key4, [])
# friends_chars.setdefault(key5, [])
# friends_chars.setdefault(key6, [])

# with open("transcripts_friends/season_all/merged.csv", "r+") as fp:
#     for cnt, line in enumerate(fp):
#         if line.startswith('Rachel:'):
#             friends_chars[key1].append(line[8:].replace("\n"," ").replace("\r",""))
#         elif line.startswith('Ross:'):
#             friends_chars[key2].append(line[6:].replace("\n"," ").replace("\r",""))
#         elif line.startswith('Monica:'):
#             friends_chars[key3].append(line[8:].replace("\n"," ").replace("\r",""))
#         elif line.startswith('Chandler:'):
#             friends_chars[key4].append(line[10:].replace("\n"," ").replace("\r",""))
#         if line.startswith('Phoebe:'):
#             friends_chars[key5].append(line[8:].replace("\n"," ").replace("\r",""))
#         if line.startswith('Joey:'):
#             friends_chars[key6].append(line[6:].replace("\n"," ").replace("\r",""))

# %%
friends_chars
# Out:
# {'RACHEL': ' Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair
barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Ooh... I can\'t believe I\'m kissing you. I\'m kissing Rachel!\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Well, I only said that because of Ross, you know. Then I saw him kissing Charlie...\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Oh my God, it\'s Ross. What are we gonna do?\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*No idea what it means.\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*I don\'t believe this... Have you guys been...\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Is he gone?\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Pssst...\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Well, he\'s with Charlie now.\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,* You\'re a pain in my ass, Geller!\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Probably, yeah... I mean, maybe we should... hold off until we talk to Ross.\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Yeah, I think that\'d be best... So, so I\'m gonna... I\'m gonna take off...\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,* I like although!\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Six years? Wow... It\'s almost as long as highschool...\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Absolutely! He\'s not thinking about you.\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*I\'m thinking about you...\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Let\'s forget about Ross...\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*What\'s wrong?\n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Well, maybe I can help. \n Barbados, Monica and Chandler\'s Room, They both enter from Ross\'s room, Monica still has her big, frizzy hair,*Yeah... we really need to talk to Ross...\n Boarding the plane,*Whoo, whoo. Wow, it\'s uhm... kinda weird that I\'m sitting next to Charlie after we broke up.\n Boarding the plane,*Look, does someone mind switching to sit with Charlie?\n Boarding the plane,*I understand...\n Boarding the plane,*I guess so. I\'m just... really nervous.\n Boarding the plane,*Ooh...\n Boarding the plane,*I\'m gonna get the lasagna.\n Boarding the plane,*Hey!\n Boarding the plane,*Yeah?\n Boarding the plane,*You kissed.\n Boarding the plane,*I saw you.\n Boarding the plane,*Ross, Ross, Ross... It\'s okay.\n Boarding the plane,*It\'s okay. You know, I totally understand, alright? You guys, make way more sense than her and I ever did, you know. And... I want you to be happy.\n Boarding the plane,*Yeah... Now I have something...\n Boarding the plane,*Oh... uh... look... before you...\n Boarding the plane,*I am those things, yeah.\n Boarding the plane,*Dude!\n Boarding the plane,*I can\'t think of anything.\n Boarding the plane,*Yeah.\n Boarding the plane,*I couldn\'t. He was saying all these really n ...

# %%
import json

with open('rachel.txt', 'w') as rachel:
    rachel.write(Rachel) 
rachel.close()

with open('monica.txt', 'w') as monica:
    monica.write(Monica) 
monica.close()

with open('ross.txt', 'w') as ross:
    ross.write(Ross) 
ross.close()

with open('phoebe.txt', 'w') as phoebe:
    phoebe.write(Phoebe) 
phoebe.close()

with open('joe.txt', 'w') as joe:
    joe.write(Joey) 
joe.close()

with open('chandler.txt', 'w') as chandler:
    chandler.write(Chandler) 
chandler.close()

# %%
df = pd.DataFrame([([k] + v) for k, v in friends_chars.items()], columns=['name','dialoguee'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-927c88ffe479> in <module>
# ----> 1 df = pd.DataFrame([([k] + v) for k, v in friends_chars.items()], columns=['name','dialoguee'])
#
# <ipython-input-24-927c88ffe479> in <listcomp>(.0)
# ----> 1 df = pd.DataFrame([([k] + v) for k, v in friends_chars.items()], columns=['name','dialoguee'])
#
# TypeError: can only concatenate list (not "str") to list

# %%
df=pd.DataFrame()
with open('rachel.txt', 'r') as rachel:
    for cnt, line in enumerate(rachel):
        tokens=line.split(':')
        df['Character']=tokens[0]
        df['text']=tokens[1]
        print(df.head())
rachel.close()

# cols=['Dialogue', 'Character']
# df=df[cols]
# Out:
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# ...
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
