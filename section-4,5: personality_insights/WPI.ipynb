# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df1 = pd.DataFrame({
    'openness': [0.48, 0.59, 0.34, 0.39, 0.80], 
    'conscientiousness': [0.88, 0.88, 0.91, 0.89, 0.81], 
    'extraversion': [0.35, 0.39, 0.37, 0.30, 0.20],
    'emotional range': [0.53, 0.45, 0.39, 0.46, 0.58],
    'agreeableness': [0.83, 0.89, 0.92, 0.85, 0.57]},
     index = ['Howard', 'Raj', 'Penny', 'Leonard', 'Sheldon']
)

# %%
df1.head()
# Out:
#          openness  conscientiousness  extraversion  emotional range  \
# Howard       0.48               0.88          0.35             0.53
# Raj          0.59               0.88          0.39             0.45
# Penny        0.34               0.91          0.37             0.39
# Leonard      0.39               0.89          0.30             0.46
# Sheldon      0.80               0.81          0.20             0.58
#
#          agreeableness
# Howard            0.83
# Raj               0.89
# Penny             0.92
# Leonard           0.85
# Sheldon           0.57

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df1.transpose().Penny, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Penny')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df1.transpose().Sheldon, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Sheldon',loc='center')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df1.transpose().Raj, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Raj',loc='center')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df1.transpose().Leonard, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Leonard',loc='center')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df1.transpose().Howard, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Howard',loc='center')
plt.show()

# %%
df1.plot(kind='bar')
plt.rcParams["figure.figsize"] = (25,10)
plt.rcParams.update({'font.size': 20})

#plt.legend(bbox_to_anchor=(0, 0), loc='left', ncol=1)
plt.show()

# %%
df1.transpose().plot(kind='bar')
plt.rcParams["figure.figsize"] = (25,10)
plt.rcParams.update({'font.size': 20})

#plt.legend(bbox_to_anchor=(0, 0), loc='center', ncol=1)
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['Openness', 'Conscientiousness', 'Extraversion', 'Emotional_Range', 'Agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df.Penny, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Sentiment Density Index for Penny')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-68709af6ef53> in <module>
#       2 labels = ['Openness', 'Conscientiousness', 'Extraversion', 'Emotional_Range', 'Agreeableness']
#       3 explode = (0.2, 0.2, 0.2, 0.2, 0.1)
# ----> 4 plt.pie(df.Penny, colors=colors, labels=labels,
#       5 explode=explode, autopct='%1.1f%%',
#       6 counterclock=False, shadow=True)
#
# NameError: name 'df' is not defined

# %%
df2 = pd.DataFrame({
    'openness': [0.92, 0.90, 0.89, 0.83, 0.87,0.92], 
    'conscientiousness': [0.00, 0.01, 0.01, 0.00, 0.00,0.00], 
    'extraversion': [0.85, 0.88, 0.82, 0.83, 0.78,0.80],
    'emotional range': [0.94, 0.91, 0.84, 0.93, 0.88,0.86],
    'agreeableness': [0.14, 0.21, 0.11, 0.22,0.17, 0.13]},
     index = ['Monica', 'Joey', 'Chandler', 'Rachel', 'Ross', 'Phoebe']
)

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df2.transpose().Monica, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Monica',loc='left')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df2.transpose().Rachel, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Rachel',loc='left')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df2.transpose().Ross, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Ross',loc='left')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df2.transpose().Chandler, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Chandler',loc='left')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df2.transpose().Phoebe, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Phoebe',loc='left')
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df2.transpose().Joey, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Joey',loc='left')
plt.show()

# %%
df2.transpose().plot(kind='bar')
plt.rcParams["figure.figsize"] = (25,10)
plt.rcParams.update({'font.size': 30})

#plt.legend(bbox_to_anchor=(0, 0), loc='center', ncol=1)
plt.show()

# %%
df2.plot(kind='bar')
plt.show()

# %%
df3 = pd.DataFrame({
    'openness': [0.91, 0.49, 0.78, 0.92, 0.71], 
    'conscientiousness': [0.02, 0.00, 0.01, 0.03, 0.01], 
    'extraversion': [0.45, 0.45, 0.57, 0.71, 0.64],
    'emotional range': [0.91, 0.97, 0.96, 0.90, 0.95],
    'agreeableness': [0.09, 0.43, 0.04, 0.26, 0.53]},
     index = ['Walter', 'Skyler', 'Jesse', 'Hank', 'Marie']
)

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df3.transpose().Walter, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Walter',loc='left')#)
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df3.transpose().Jesse, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Jesse',loc='left')#)
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df3.transpose().Skyler, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Skyler',loc='left')#)
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df3.transpose().Marie, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Marie',loc='left')#)
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df3.transpose().Hank, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Hank',loc='left')#)
plt.show()

# %%
colors = ['b', 'g', 'r', 'c', 'm']
labels = ['openness', 'conscientiousness', 'extraversion', 'emotional range', 'agreeableness']
explode = (0.2, 0.2, 0.2, 0.2, 0.1)
plt.pie(df3.transpose().Walter, colors=colors, labels=labels,
explode=explode, autopct='%1.1f%%',
counterclock=False, shadow=True)
plt.title('Personality Density Index for Walter')#)
plt.show()

# %%
df3.transpose().plot(kind='bar')
plt.rcParams["figure.figsize"] = (25,10)
plt.rcParams.update({'font.size': 20})

#plt.legend(bbox_to_anchor=(0, 0), loc='center', ncol=1)
plt.show()

# %%
df3.plot(kind='bar')
plt.show()
